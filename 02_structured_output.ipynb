# %%
from pydantic import BaseModel, Field
from typing import List

from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.7)

# %%
class CityActivities(BaseModel):
    city: str
    interests: List[str]
    suggested_activities: List[str] = Field(description="Suggested, short activities (3-5).")
    confidence: float = Field(ge=0, le=1)

structured_llm = llm.with_structured_output(CityActivities)

resp = structured_llm.invoke(
    "I like food i museums. I will visit Poznań — show me propositions."
)
resp
# Out:
# CityActivities(city='Poznań', interests=['Food', 'Museums'], suggested_activities=["Visit the Croissant Museum to learn about the famous St. Martin's croissants and enjoy a tasting.", 'Explore the National Museum in Poznań, which houses a rich collection of Polish art.', 'Take a walking food tour to sample local dishes and learn about the culinary history of the city.', 'Visit the Museum of Musical Instruments, showcasing a variety of instruments from different cultures.', 'Dine at a traditional Polish restaurant to experience authentic cuisine.'], confidence=0.9)
